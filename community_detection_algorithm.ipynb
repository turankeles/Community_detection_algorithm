# %%
import os 
#uploading necessary modules
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx
import community
import pandas as pd

# %%
os.chdir("C:\\Users\\turan\\Desktop")
os.getcwd()
# Out:
# 'C:\\Users\\turan\\Desktop'

# %%
#Higgsboson particle
#Twitter followers data 
for i in os.listdir():
    if "social" in i:
        social=pd.read_csv(i)

# %%
soc.shape
# Out:
# (14855841, 1)

# %%
soc=[i.split() for i in social.iloc[:,0]]
soc=pd.DataFrame(soc)
soc
# Out:
#                0       1
# 0              1       3
# 1              1       4
# 2              1       5
# 3              1       6
# 4              1       7
# ...          ...     ...
# 14855836  456624       1
# 14855837  456625     220
# 14855838  421799   81585
# 14855839  421799  100470
# 14855840  456626       1
#
# [14855841 rows x 2 columns]

# %%
soc.columns=["a","b"]
soc
# Out:
#                a       b
# 0              1       3
# 1              1       4
# 2              1       5
# 3              1       6
# 4              1       7
# ...          ...     ...
# 14855836  456624       1
# 14855837  456625     220
# 14855838  421799   81585
# 14855839  421799  100470
# 14855840  456626       1
#
# [14855841 rows x 2 columns]

# %%
soc_graph=nx.from_pandas_edgelist(soc,"a","b")

# %%
nx.info(soc_graph)
# Out:
# 'Graph with 5535 nodes and 9911 edges'

# %%
#modularity coefficient
import networkx as nx
import community
import networkx.algorithms.community as nx_comm

# %%
partition_soc=community_louvain.best_partition(soc_graph)#partition

# %%
from community import community_louvain

# %%
pos_soc = nx.spring_layout(soc_graph)

# %%
#plotting
plt.figure(figsize=(10,8))
plt.style.use("seaborn")
cmap = cm.get_cmap('magma', max(partition_soc.values()) + 1)
nx.draw_networkx_nodes(soc_graph, pos_soc, partition_soc.keys(), node_size=40,
                       cmap=cmap, node_color=list(partition_soc.values()))
nx.draw_networkx_edges(soc_graph,pos_soc, alpha=0.5)
plt.title("community detection followers")
plt.show()

# %%
# nx_comm.modularity(soc_graph, nx_comm.label_propagation_communities(soc_graph) louvian is more relevant
# Out:
# 0.48660376818929113

# %%
participation coeefficient; about distribution

# %%
import community
community.modularity(partition_soc,soc_graph)

# %%
#modularity coefficient for followers
modularity_followers=community_louvain.modularity(partition_soc,soc_graph)
print("modularity for followers :",modularity_followers)
# Out:
# modularity for followers : 0.5932464711331924
